# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
iris=pd.read_csv(r'D:\EDA\IRIS DATASET _ ADVANCE VISUALIZATION _ EDA 2\Iris.csv')

# %%
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.drop('Id',axis=1,inplace=True)

# %%
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
sns.countplot('Species',data=iris)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 sns.countplot('Species',data=iris)
#       2 plt.show()
#
# TypeError: countplot() got multiple values for argument 'data'

# %%
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
fig=sns.jointplot(x='SepalLengthCm',y='SepalWidthCm',data=iris)

# %%
sns.jointplot(data=iris,x="SepalWidthCm",y="SepalLengthCm",kind='reg')
plt.show()

# %%
sns.jointplot(data=iris,x="SepalWidthCm",y="SepalLengthCm",kind='hex')
plt.show()

# %%
sns.jointplot(data=iris,x="SepalWidthCm",y="SepalLengthCm",hue="Species")
plt.show()

# %%
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.boxplot(data=iris,x="SepalWidthCm",y="SepalLengthCm",hue="Species")
plt.show()

# %%
sns.boxplot(data=iris,x="SepalWidthCm",y="SepalLengthCm",)
plt.show()

# %%
iris.boxplot(by="Species",figsize=(12,6))
# Out:
# array([[<Axes: title={'center': 'PetalLengthCm'}, xlabel='[Species]'>,
#         <Axes: title={'center': 'PetalWidthCm'}, xlabel='[Species]'>],
#        [<Axes: title={'center': 'SepalLengthCm'}, xlabel='[Species]'>,
#         <Axes: title={'center': 'SepalWidthCm'}, xlabel='[Species]'>]],
#       dtype=object)

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.stripplot(data=iris,jitter=True,edgecolor='gray',size=8)

# %%
fig=plt.gcf()
fig=sns.boxplot(data=iris,x='Species',y='SepalLengthCm')
fig=sns.stripplot(data=iris,x='Species',y='SepalLengthCm',jitter=True)

# %%
fig=plt.gcf()
ax=fig=sns.boxplot(data=iris,x='Species',y='SepalLengthCm')
ax=fig=sns.stripplot(data=iris,x='Species',y='SepalLengthCm',jitter=True)
boxtwo=ax.artists[2]
boxtwo.set_facecolor('yellow')
boxtwo.set_edgecolor('black')
boxthree=ax.artists[1]
boxthree.set_facecolor('red')
boxthree.set_edgecolor('black')
boxthree=ax.artists[0]
boxthree.set_facecolor('green')
boxthree.set_edgecolor('black')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[40], line 4
#       2 ax=fig=sns.boxplot(data=iris,x='Species',y='SepalLengthCm')
#       3 ax=fig=sns.stripplot(data=iris,x='Species',y='SepalLengthCm',jitter=True)
# ----> 4 boxtwo=ax.artists[2]
#       5 boxtwo.set_facecolor('yellow')
#       6 boxtwo.set_edgecolor('black')
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:1457, in _AxesBase.ArtistList.__getitem__(self, key)
#    1456 def __getitem__(self, key):
# -> 1457     return [artist
#    1458             for artist in self._axes._children
#    1459             if self._type_check(artist)][key]
#
# IndexError: list index out of range

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.violinplot(data=iris,x='Species',y='SepalLengthCm')

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.violinplot(x='Species',y='PetalLengthCm',data=iris)
plt.subplot(2,2,2)
sns.violinplot(x='Species',y='PetalWidthCm',data=iris)
plt.subplot(2,2,3)
sns.violinplot(x='Species',y='SepalLengthCm',data=iris)
plt.subplot(2,2,4)
sns.violinplot(x='Species',y='SepalWidthCm',data=iris)
# Out:
# <Axes: xlabel='Species', ylabel='SepalWidthCm'>

# %%
sns.pairplot(data=iris,kind='scatter',hue='Species')

# %%
sns.pairplot(data=iris,kind='scatter',)

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.heatmap(iris.corr(),annot=True,cmap='cubehelix',linewidths=1,linecolor='k',square=True,mask=False,vmin=-1, vmax=1,cbar_kws={"orientation": "vertical"},cbar=True)
